# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
os.chdir('/home/sidrah19220/nmd_review/comment4/wild/immature')

# %%
eud_orig = pd.read_csv('euclidean.csv', index_col =0)
exp = pd.read_csv('matrix-5-Expression.csv', index_col = 0)

# %%
sub1 = eud_orig[2558:]
col = sub1.index.tolist()
sub2 = sub1[col]
eud = sub2
eud.to_csv('imt-imt-euc.csv')

# %% [markdown]
# MATURE IMMATURE PAIR

# %%
#MAKE A LIST OF ALL ORS AND CELLS AND TRANSPOSE THE EXP MATRIX
olf_rec = exp.columns.tolist()
ors=list(exp.columns.values.tolist())
cells=exp.index.values
#exp.index = cells
tr_exp=exp.T

# %%
#CHECK IF THE CELL EXPRESSES MORE THAN 8 ORS THEN APPEND THE CELL ID 
all_ors={}
zero_exp=[]
for cell in cells:
    all_ors[cell]=[]
    cell_exps=sorted(tr_exp[cell].tolist(), reverse=True)
    if cell_exps[0]>0:
        if tr_exp[cell].tolist().count(max(cell_exps)) > 8:
            for i in range(tr_exp[cell].tolist().count(max(tr_exp[cell]))):
                all_ors[cell].append(tr_exp.sort_values(by=cell, ascending=False).index[i])
        else:
            for i in range(8):
                if cell_exps[i]>0:
                    all_ors[cell].append(tr_exp.sort_values(by=cell, ascending=False).index[i])
    else:
        zero_exp.append(cell)

# %%
cell_imt={}
cell_imm={}
cell_mat={}
for key,value in all_ors.items():
  if key.startswith("IMT"):
    cell_imt[key]=[]
    for val in value:
      if val.startswith("Olfm"):
        continue
      else:
        cell_imt[key].append(val)
  if key.startswith("MA"):
    cell_mat[key]=[]
    for val in value:
      if val.startswith("Olfm"):
        continue
      else:
        cell_mat[key].append(val)
  if key.startswith("IMM"):
    for val in value:
      cell_imm[key]=[]
      if val.startswith("Olfm"):
        continue
      else:
        cell_imm[key].append(val)

# %%
#TO TREAT IMMATURE AND TRANSITION AS ONE, MERGE THE DICTIONARY
cell_imm_imt={}
for key,value in all_ors.items():
    if key.startswith("IMM"):
        cell_imm_imt[key]=[]
        for val in value:
            if val.startswith("Olfm"):
                continue
            else:
                cell_imm_imt[key].append(val)

# %%
cell_mat = cell_imm_imt.copy()

# %%
cell_mat
# Out:
# {'IMMATURE CELL1': [],
#  'IMMATURE CELL2': [],
#  'IMMATURE CELL3': ['Olfr325'],
#  'IMMATURE CELL4': [],
#  'IMMATURE CELL5': [],
#  'IMMATURE CELL6': [],
#  'IMMATURE CELL7': [],
#  'IMMATURE CELL8': ['Olfr115'],
#  'IMMATURE CELL9': [],
#  'IMMATURE CELL10': ['Olfr1076'],
#  'IMMATURE CELL11': [],
#  'IMMATURE CELL12': ['Olfr93'],
#  'IMMATURE CELL13': ['Olfr1062'],
#  'IMMATURE CELL14': ['Olfr112'],
#  'IMMATURE CELL15': [],
#  'IMMATURE CELL16': [],
#  'IMMATURE CELL17': ['Olfr135'],
#  'IMMATURE CELL18': ['Olfr1320'],
#  'IMMATURE CELL19': ['Olfr411'],
#  'IMMATURE CELL20': ['Olfr220'],
#  'IMMATURE CELL21': [],
#  'IMMATURE CELL22': ['Olfr1500'],
#  'IMMATURE CELL23': [],
#  'IMMATURE CELL24': ['Olfr1076'],
#  'IMMATURE CELL25': [],
#  'IMMATURE CELL26': ['Olfr420', 'Olfr745'],
#  'IMMATURE CELL27': [],
#  'IMMATURE CELL28': ['Olfr1444', 'Olfr1222'],
#  'IMMATURE CELL29': [],
#  'IMMATURE CELL30': [],
#  'IMMATURE CELL31': [],
#  'IMMATURE CELL32': ['Olfr1132', 'Olfr112', 'Olfr816'],
#  'IMMATURE CELL33': [],
#  'IMMATURE CELL34': [],
#  'IMMATURE CELL35': [],
#  'IMMATURE CELL36': [],
#  'IMMATURE CELL37': ['Olfr209'],
#  'IMMATURE CELL38': [],
#  'IMMATURE CELL39': ['Olfr707'],
#  'IMMATURE CELL40': ['Olfr325'],
#  'IMMATURE CELL41': ['Olfr741'],
#  'IMMATURE CELL42': ['Olfr695'],
#  'IMMATURE CELL43': ['Olfr1093'],
#  'IMMATURE CELL44': [],
#  'IMMATURE CELL45': ['Olfr1364'],
#  'IMMATURE CELL46': [],
#  'IMMATURE CELL47': [],
#  'IMMATURE CELL48': [],
#  'IMMATURE CELL49': [],
#  'IMMATURE CELL50': [],
#  'IMMATURE CELL51': ['Olfr1537'],
#  'IMMATURE CELL52': [],
#  'IMMATURE CELL53': [],
#  'IMMATURE CELL54': [],
#  'IMMATURE CELL55': [],
#  'IMMATURE CELL56': [],
#  'IMMATURE CELL57': [],
#  'IMMATURE CELL58': [],
#  'IMMATURE CELL59': ['Olfr341'],
#  'IMMATURE CELL60': ['Olfr1232'],
#  'IMMATURE CELL61': [],
#  'IMMATURE CELL62': [],
#  'IMMATURE CELL63': [],
#  'IMMATURE CELL64': ['Olfr368', 'Olfr749'],
#  'IMMATURE CELL65': ['Olfr1286'],
#  'IMMATURE CELL66': ['Olfr955'],
#  'IMMATURE CELL67': ['Olfr493', 'Olfr492'],
#  'IMMATURE CELL68': ['Olfr116'],
#  'IMMATURE CELL69': [],
#  'IMMATURE CELL70': [],
#  'IMMATURE CELL71': [],
#  'IMMATURE CELL72': ['Olfr1444'],
#  'IMMATURE CELL73': [],
#  'IMMATURE CELL74': [],
#  'IMMATURE CELL75': [],
#  'IMMATURE CELL76': [],
#  'IMMATURE CELL77': ['Olfr963'],
#  'IMMATURE CELL78': [],
#  'IMMATURE CELL79': ['Olfr1046'],
#  'IMMATURE CELL80': [],
#  'IMMATURE CELL81': [],
#  'IMMATURE CELL82': [],
#  'IMMATURE CELL83': [],
#  'IMMATURE CELL84': [],
#  'IMMATURE CELL85': [],
#  'IMMATURE CELL86': ['Olfr1195'],
#  'IMMATURE CELL87': ['Olfr1434'],
#  'IMMATURE CELL88': [],
#  'IMMATURE CELL89': ['Olfr299', 'Olfr1484', 'Olfr1297'],
#  'IMMATURE CELL90': [],
#  'IMMATURE CELL91': ['Olfr849'],
#  'IMMATURE CELL92': ['Olfr869'],
#  'IMMATURE CELL93': ['Olfr165'],
#  'IMMATURE CELL94': [],
#  'IMMATURE CELL95': ['Olfr183'],
#  'IMMATURE CELL96': ['Olfr1120'],
#  'IMMATURE CELL97': ['Olfr1335', 'Olfr1031'],
#  'IMMATURE CELL98': ['Olfr55'],
#  'IMMATURE CELL99': [],
#  'IMMATURE CELL100': [],
#  'IMMATURE CELL101': [],
#  'IMMATURE CELL102': ['Olfr1532.ps1'],
#  'IMMATURE CELL103': [],
#  'IMMATURE CELL104': [],
#  'IMMATURE CELL105': [],
#  'IMMATURE CELL106': [],
#  'IMMATURE CELL107': [],
#  'IMMATURE CELL108': [],
#  'IMMATURE CELL109': [],
#  'IMMATURE CELL110': ['Olfr1448'],
#  'IMMATURE CELL111': [],
#  'IMMATURE CELL112': ['Olfr297'],
#  'IMMATURE CELL113': [],
#  'IMMATURE CELL114': ['Olfr945'],
#  'IMMATURE CELL115': [],
#  'IMMATURE CELL116': [],
#  'IMMATURE CELL117': ['Olfr556'],
#  'IMMATURE CELL118': [],
#  'IMMATURE CELL119': ['Olfr801', 'Olfr1356'],
#  'IMMATURE CELL120': ['Olfr1109'],
#  'IMMATURE CELL121': ['Olfr517', 'Olfr103', 'Olfr205', 'Olfr1480', 'Olfr860'],
#  'IMMATURE CELL122': ['Olfr1124'],
#  'IMMATURE CELL123': [],
#  'IMMATURE CELL124': [],
#  'IMMATURE CELL125': [],
#  'IMMATURE CELL126': ['Olfr97'],
#  'IMMATURE CELL127': [],
#  'IMMATURE CELL128': ['Olfr826'],
#  'IMMATURE CELL129': [],
#  'IMMATURE CELL130': [],
#  'IMMATURE CELL131': ['Olfr1423'],
#  'IMMATURE CELL132': ['Olfr1120'],
#  'IMMATURE CELL133': ['Olfr1338', 'Olfr371'],
#  'IMMATURE CELL134': ['Olfr31'],
#  'IMMATURE CELL135': ['Olfr829', 'Olfr39'],
#  'IMMATURE CELL136': [],
#  'IMMATURE CELL137': [],
#  'IMMATURE CELL138': ['Olfr697', 'Olfr749', 'Olfr772', 'Olfr181'],
#  'IMMATURE CELL139': [],
#  'IMMATURE CELL140': ['Olfr411'],
#  'IMMATURE CELL141': ['Olfr220'],
#  'IMMATURE CELL142': [],
#  'IMMATURE CELL143': [],
#  'IMMATURE CELL144': [],
#  'IMMATURE CELL145': [],
#  'IMMATURE CELL146': ['Olfr1453'],
#  'IMMATURE CELL147': [],
#  'IMMATURE CELL148': ['Olfr916'],
#  'IMMATURE CELL149': [],
#  'IMMATURE CELL150': [],
#  'IMMATURE CELL151': [],
#  'IMMATURE CELL152': ['Olfr382'],
#  'IMMATURE CELL153': [],
#  'IMMATURE CELL154': ['Olfr789'],
#  'IMMATURE CELL155': [],
#  'IMMATURE CELL156': ['Olfr1294'],
#  'IMMATURE CELL157': [],
#  'IMMATURE CELL158': ['Olfr1254'],
#  'IMMATURE CELL159': [],
#  'IMMATURE CELL160': [],
#  'IMMATURE CELL161': ['Olfr27'],
#  'IMMATURE CELL162': [],
#  'IMMATURE CELL163': ['Olfr380'],
#  'IMMATURE CELL164': ['Olfr1384'],
#  'IMMATURE CELL165': [],
#  'IMMATURE CELL166': ['Olfr912'],
#  'IMMATURE CELL167': [],
#  'IMMATURE CELL168': [],
#  'IMMATURE CELL169': [],
#  'IMMATURE CELL170': [],
#  'IMMATURE CELL171': [],
#  'IMMATURE CELL172': [],
#  'IMMATURE CELL173': [],
#  'IMMATURE CELL174': ['Olfr55'],
#  'IMMATURE CELL175': [],
#  'IMMATURE CELL176': ['Olfr394'],
#  'IMMATURE CELL177': ['Olfr1317'],
#  'IMMATURE CELL178': [],
#  'IMMATURE CELL179': ['Olfr1123'],
#  'IMMATURE CELL180': [],
#  'IMMATURE CELL181': [],
#  'IMMATURE CELL182': ['Olfr1241'],
#  'IMMATURE CELL183': [],
#  'IMMATURE CELL184': ['Olfr1537', 'Olfr173'],
#  'IMMATURE CELL185': ['Olfr140'],
#  'IMMATURE CELL186': ['Olfr1441', 'Olfr855', 'Olfr168'],
#  'IMMATURE CELL187': [],
#  'IMMATURE CELL188': [],
#  'IMMATURE CELL189': ['Olfr921'],
#  'IMMATURE CELL190': [],
#  'IMMATURE CELL191': [],
#  'IMMATURE CELL192': ['Olfr1265'],
#  'IMMATURE CELL193': [],
#  'IMMATURE CELL194': [],
#  'IMMATURE CELL195': [],
#  'IMMATURE CELL196': ['Olfr391.ps'],
#  'IMMATURE CELL197': [],
#  'IMMATURE CELL198': ['Olfr1082'],
#  'IMMATURE CELL199': ['Olfr181'],
#  'IMMATURE CELL200': [],
#  'IMMATURE CELL201': ['Olfr1138'],
#  'IMMATURE CELL202': [],
#  'IMMATURE CELL203': ['Olfr701'],
#  'IMMATURE CELL204': [],
#  'IMMATURE CELL205': [],
#  'IMMATURE CELL206': ['Olfr702'],
#  'IMMATURE CELL207': ['Olfr237.ps1', 'Olfr403'],
#  'IMMATURE CELL208': [],
#  'IMMATURE CELL209': ['Olfr187'],
#  'IMMATURE CELL210': ['Olfr328'],
#  'IMMATURE CELL211': [],
#  'IMMATURE CELL212': ['Olfr788'],
#  'IMMATURE CELL213': ['Olfr315', 'Olfr711'],
#  'IMMATURE CELL214': [],
#  'IMMATURE CELL215': ['Olfr538'],
#  'IMMATURE CELL216': ['Olfr23', 'Olfr181'],
#  'IMMATURE CELL217': ['Olfr1006'],
#  'IMMATURE CELL218': ['Olfr1030'],
#  'IMMATURE CELL219': ['Olfr1424'],
#  'IMMATURE CELL220': [],
#  'IMMATURE CELL221': [],
#  'IMMATURE CELL222': [],
#  'IMMATURE CELL223': [],
#  'IMMATURE CELL224': [],
#  'IMMATURE CELL225': [],
#  'IMMATURE CELL226': [],
#  'IMMATURE CELL227': [],
#  'IMMATURE CELL228': ['Olfr70'],
#  'IMMATURE CELL229': [],
#  'IMMATURE CELL230': [],
#  'IMMATURE CELL231': ['Olfr220', 'Olfr206'],
#  'IMMATURE CELL232': ['Olfr1314', 'Olfr1428'],
#  'IMMATURE CELL233': [],
#  'IMMATURE CELL234': [],
#  'IMMATURE CELL235': [],
#  'IMMATURE CELL236': [],
#  'IMMATURE CELL237': ['Olfr722'],
#  'IMMATURE CELL238': [],
#  'IMMATURE CELL239': [],
#  'IMMATURE CELL240': [],
#  'IMMATURE CELL241': [],
#  'IMMATURE CELL242': [],
#  'IMMATURE CELL243': [],
#  'IMMATURE CELL244': ['Olfr1301'],
#  'IMMATURE CELL245': [],
#  'IMMATURE CELL246': [],
#  'IMMATURE CELL247': ['Olfr806'],
#  'IMMATURE CELL248': ['Olfr167'],
#  'IMMATURE CELL249': [],
#  'IMMATURE CELL250': [],
#  'IMMATURE CELL251': [],
#  'IMMATURE CELL252': ['Olfr722', 'Olfr1428'],
#  'IMMATURE CELL253': ['Olfr220'],
#  'IMMATURE CELL254': ['Olfr1348'],
#  'IMMATURE CELL255': ['Olfr434',
#   'Olfr1308',
#   'Olfr115',
#   'Olfr1477',
#   'Olfr1250',
#   'Olfr701',
#   'Olfr1437'],
#  'IMMATURE CELL256': ['Olfr1133', 'Olfr549'],
#  'IMMATURE CELL257': ['Olfr607', 'Olfr1511'],
#  'IMMATURE CELL258': [],
#  'IMMATURE CELL259': ['Olfr791', 'Olfr115', 'Olfr1301'],
#  'IMMATURE CELL260': [],
#  'IMMATURE CELL261': ['Olfr44', 'Olfr111', 'Olfr173', 'Olfr594'],
#  'IMMATURE CELL262': [],
#  'IMMATURE CELL263': ['Olfr1348'],
#  'IMMATURE CELL264': ['Olfr1184', 'Olfr538', 'Olfr1437'],
#  'IMMATURE CELL265': ['Olfr297'],
#  'IMMATURE CELL266': ['Olfr536'],
#  'IMMATURE CELL267': [],
#  'IMMATURE CELL268': [],
#  'IMMATURE CELL269': ['Olfr1276'],
#  'IMMATURE CELL270': [],
#  'IMMATURE CELL271': [],
#  'IMMATURE CELL272': ['Olfr1383'],
#  'IMMATURE CELL273': [],
#  'IMMATURE CELL274': ['Olfr1288'],
#  'IMMATURE CELL275': ['Olfr464'],
#  'IMMATURE CELL276': [],
#  'IMMATURE CELL277': ['Olfr1440'],
#  'IMMATURE CELL278': ['Olfr1079', 'Olfr1080'],
#  'IMMATURE CELL279': [],
#  'IMMATURE CELL280': [],
#  'IMMATURE CELL281': ['Olfr209'],
#  'IMMATURE CELL282': ['Olfr1130', 'Olfr284', 'Olfr1354', 'Olfr360'],
#  'IMMATURE CELL283': [],
#  'IMMATURE CELL284': ['Olfr1463', 'Olfr711'],
#  'IMMATURE CELL285': [],
#  'IMMATURE CELL286': ['Olfr772',
#   'Olfr235',
#   'Olfr121',
#   'Olfr479',
#   'Olfr1491',
#   'Olfr131'],
#  'IMMATURE CELL287': ['Olfr1116', 'Olfr533', 'Olfr722'],
#  'IMMATURE CELL288': ['Olfr536'],
#  'IMMATURE CELL289': ['Olfr1196'],
#  'IMMATURE CELL290': [],
#  'IMMATURE CELL291': [],
#  'IMMATURE CELL292': [],
#  'IMMATURE CELL293': ['Olfr139'],
#  'IMMATURE CELL294': ['Olfr344', 'Olfr1326.ps1'],
#  'IMMATURE CELL295': [],
#  'IMMATURE CELL296': ['Olfr293', 'Olfr169'],
#  'IMMATURE CELL297': ['Olfr855', 'Olfr1428'],
#  'IMMATURE CELL298': ['Olfr1265', 'Olfr1222', 'Olfr1426'],
#  'IMMATURE CELL299': ['Olfr1106'],
#  'IMMATURE CELL300': [],
#  'IMMATURE CELL301': ['Olfr704'],
#  'IMMATURE CELL302': ['Olfr293', 'Olfr132'],
#  'IMMATURE CELL303': [],
#  'IMMATURE CELL304': ['Olfr1208', 'Olfr131'],
#  'IMMATURE CELL305': [],
#  'IMMATURE CELL306': ['Olfr820'],
#  'IMMATURE CELL307': ['Olfr802'],
#  'IMMATURE CELL308': ['Olfr1136', 'Olfr460', 'Olfr1458', 'Olfr202', 'Olfr131'],
#  'IMMATURE CELL309': ['Olfr1030'],
#  'IMMATURE CELL310': [],
#  'IMMATURE CELL311': ['Olfr711'],
#  'IMMATURE CELL312': [],
#  'IMMATURE CELL313': [],
#  'IMMATURE CELL314': [],
#  'IMMATURE CELL315': [],
#  'IMMATURE CELL316': ['Olfr430'],
#  'IMMATURE CELL317': ['Olfr1124'],
#  'IMMATURE CELL318': ['Olfr1423'],
#  'IMMATURE CELL319': ['Olfr368'],
#  'IMMATURE CELL320': [],
#  'IMMATURE CELL321': ['Olfr374'],
#  'IMMATURE CELL322': ['Olfr1414'],
#  'IMMATURE CELL323': ['Olfr1440'],
#  'IMMATURE CELL324': ['Olfr935', 'Olfr330'],
#  'IMMATURE CELL325': [],
#  'IMMATURE CELL326': [],
#  'IMMATURE CELL327': [],
#  'IMMATURE CELL328': ['Olfr459'],
#  'IMMATURE CELL329': [],
#  'IMMATURE CELL330': ['Olfr1188', 'Olfr1086', 'Olfr829', 'Olfr1229'],
#  'IMMATURE CELL331': ['Olfr745', 'Olfr869', 'Olfr1301'],
#  'IMMATURE CELL332': [],
#  'IMMATURE CELL333': ['Olfr1426'],
#  'IMMATURE CELL334': ['Olfr722'],
#  'IMMATURE CELL335': ['Olfr1140'],
#  'IMMATURE CELL336': ['Olfr658', 'Olfr175.ps1', 'Olfr1364'],
#  'IMMATURE CELL337': [],
#  'IMMATURE CELL338': [],
#  'IMMATURE CELL339': ['Olfr212'],
#  'IMMATURE CELL340': ['Olfr330', 'Olfr212'],
#  'IMMATURE CELL341': [],
#  'IMMATURE CELL342': [],
#  'IMMATURE CELL343': ['Olfr1428'],
#  'IMMATURE CELL344': ['Olfr1509'],
#  'IMMATURE CELL345': ['Olfr822'],
#  'IMMATURE CELL346': [],
#  'IMMATURE CELL347': ['Olfr209'],
#  'IMMATURE CELL348': [],
#  'IMMATURE CELL349': [],
#  'IMMATURE CELL350': [],
#  'IMMATURE CELL351': [],
#  'IMMATURE CELL352': [],
#  'IMMATURE CELL353': [],
#  'IMMATURE CELL354': ['Olfr799'],
#  'IMMATURE CELL355': ['Olfr464'],
#  'IMMATURE CELL356': [],
#  'IMMATURE CELL357': ['Olfr866', 'Olfr464'],
#  'IMMATURE CELL358': [],
#  'IMMATURE CELL359': [],
#  'IMMATURE CELL360': [],
#  'IMMATURE CELL361': ['Olfr293'],
#  'IMMATURE CELL362': [],
#  'IMMATURE CELL363': [],
#  'IMMATURE CELL364': [],
#  'IMMATURE CELL365': [],
#  'IMMATURE CELL366': ['Olfr339'],
#  'IMMATURE CELL367': [],
#  'IMMATURE CELL368': ['Olfr54', 'Olfr1112'],
#  'IMMATURE CELL369': [],
#  'IMMATURE CELL370': ['Olfr1537', 'Olfr53', 'Olfr297'],
#  'IMMATURE CELL371': [],
#  'IMMATURE CELL372': [],
#  'IMMATURE CELL373': ['Olfr613', 'Olfr1424', 'Olfr479'],
#  'IMMATURE CELL374': [],
#  'IMMATURE CELL375': ['Olfr1152', 'Olfr709.ps1', 'Olfr39'],
#  'IMMATURE CELL376': [],
#  'IMMATURE CELL377': ['Olfr901'],
#  'IMMATURE CELL378': [],
#  'IMMATURE CELL379': ['Olfr206'],
#  'IMMATURE CELL380': ['Olfr726'],
#  'IMMATURE CELL381': ['Olfr297'],
#  'IMMATURE CELL382': [],
#  'IMMATURE CELL383': ['Olfr212'],
#  'IMMATURE CELL384': [],
#  'IMMATURE CELL385': ['Olfr1015'],
#  'IMMATURE CELL386': [],
#  'IMMATURE CELL387': [],
#  'IMMATURE CELL388': ['Olfr1301'],
#  'IMMATURE CELL389': [],
#  'IMMATURE CELL390': ['Olfr701'],
#  'IMMATURE CELL391': [],
#  'IMMATURE CELL392': [],
#  'IMMATURE CELL393': [],
#  'IMMATURE CELL394': ['Olfr266', 'Olfr187'],
#  'IMMATURE CELL395': ['Olfr855', 'Olfr745', 'Olfr536', 'Olfr53'],
#  'IMMATURE CELL396': [],
#  'IMMATURE CELL397': ['Olfr917', 'Olfr53'],
#  'IMMATURE CELL398': [],
#  'IMMATURE CELL399': ['Olfr177', 'Olfr175.ps1'],
#  'IMMATURE CELL400': ['Olfr726'],
#  'IMMATURE CELL401': ['Olfr944'],
#  'IMMATURE CELL402': [],
#  'IMMATURE CELL403': ['Olfr1289', 'Olfr1500'],
#  'IMMATURE CELL404': ['Olfr729'],
#  'IMMATURE CELL405': [],
#  'IMMATURE CELL406': [],
#  'IMMATURE CELL407': ['Olfr1423'],
#  'IMMATURE CELL408': ['Olfr695'],
#  'IMMATURE CELL409': [],
#  'IMMATURE CELL410': [],
#  'IMMATURE CELL411': [],
#  'IMMATURE CELL412': [],
#  'IMMATURE CELL413': ['Olfr180'],
#  'IMMATURE CELL414': [],
#  'IMMATURE CELL415': [],
#  'IMMATURE CELL416': ['Olfr131'],
#  'IMMATURE CELL417': ['Olfr749'],
#  'IMMATURE CELL418': ['Olfr855', 'Olfr209'],
#  'IMMATURE CELL419': [],
#  'IMMATURE CELL420': [],
#  'IMMATURE CELL421': [],
#  'IMMATURE CELL422': ['Olfr672'],
#  'IMMATURE CELL423': ['Olfr212'],
#  'IMMATURE CELL424': [],
#  'IMMATURE CELL425': ['Olfr44', 'Olfr181', 'Olfr536'],
#  'IMMATURE CELL426': ['Olfr781'],
#  'IMMATURE CELL427': [],
#  'IMMATURE CELL428': ['Olfr1056', 'Olfr1301'],
#  'IMMATURE CELL429': ['Olfr727', 'Olfr1420'],
#  'IMMATURE CELL430': ['Olfr1104', 'Olfr330'],
#  'IMMATURE CELL431': ['Olfr1014', 'Olfr799'],
#  'IMMATURE CELL432': [],
#  'IMMATURE CELL433': ['Olfr944'],
#  'IMMATURE CELL434': ['Olfr1247'],
#  'IMMATURE CELL435': [],
#  'IMMATURE CELL436': ['Olfr1420', 'Olfr1392', 'Olfr1440', 'Olfr1297'],
#  'IMMATURE CELL437': ['Olfr1508'],
#  'IMMATURE CELL438': ['Olfr1362', 'Olfr1222'],
#  'IMMATURE CELL439': [],
#  'IMMATURE CELL440': [],
#  'IMMATURE CELL441': ['Olfr745'],
#  'IMMATURE CELL442': [],
#  'IMMATURE CELL443': ['Olfr1440'],
#  'IMMATURE CELL444': ['Olfr1420', 'Olfr1080'],
#  'IMMATURE CELL445': ['Olfr6'],
#  'IMMATURE CELL446': ['Olfr1423', 'Olfr309'],
#  'IMMATURE CELL447': [],
#  'IMMATURE CELL448': [],
#  'IMMATURE CELL449': [],
#  'IMMATURE CELL450': ['Olfr670', 'Olfr672'],
#  'IMMATURE CELL451': [],
#  'IMMATURE CELL452': ['Olfr1357'],
#  'IMMATURE CELL453': ['Olfr1087'],
#  'IMMATURE CELL454': [],
#  'IMMATURE CELL455': [],
#  'IMMATURE CELL456': ['Olfr1168', 'Olfr1276'],
#  'IMMATURE CELL457': ['Olfr131'],
#  'IMMATURE CELL458': ['Olfr866'],
#  'IMMATURE CELL459': ['Olfr1118', 'Olfr1440'],
#  'IMMATURE CELL460': [],
#  'IMMATURE CELL461': ['Olfr722'],
#  'IMMATURE CELL462': ['Olfr1408'],
#  'IMMATURE CELL463': [],
#  'IMMATURE CELL464': ['Olfr1022', 'Olfr572'],
#  'IMMATURE CELL465': ['Olfr213', 'Olfr1124'],
#  'IMMATURE CELL466': [],
#  'IMMATURE CELL467': [],
#  'IMMATURE CELL468': [],
#  'IMMATURE CELL469': [],
#  'IMMATURE CELL470': ['Olfr267'],
#  'IMMATURE CELL471': ['Olfr745', 'Olfr972'],
#  'IMMATURE CELL472': ['Olfr1084', 'Olfr121'],
#  'IMMATURE CELL473': ['Olfr1241'],
#  'IMMATURE CELL474': [],
#  'IMMATURE CELL475': ['Olfr1104'],
#  'IMMATURE CELL476': [],
#  'IMMATURE CELL477': [],
#  'IMMATURE CELL478': [],
#  'IMMATURE CELL479': ['Olfr385', 'Olfr77', 'Olfr1229'],
#  'IMMATURE CELL480': [],
#  'IMMATURE CELL481': [],
#  'IMMATURE CELL482': ['Olfr701'],
#  'IMMATURE CELL483': ['Olfr462', 'Olfr1357'],
#  'IMMATURE CELL484': ['Olfr1297'],
#  'IMMATURE CELL485': ['Olfr115'],
#  'IMMATURE CELL486': ['Olfr1276', 'Olfr711'],
#  'IMMATURE CELL487': [],
#  'IMMATURE CELL488': ['Olfr697'],
#  'IMMATURE CELL489': ['Olfr536'],
#  'IMMATURE CELL490': ['Olfr297'],
#  'IMMATURE CELL491': [],
#  'IMMATURE CELL492': [],
#  'IMMATURE CELL493': ['Olfr59'],
#  'IMMATURE CELL494': ['Olfr986'],
#  'IMMATURE CELL495': [],
#  'IMMATURE CELL496': [],
#  'IMMATURE CELL497': [],
#  'IMMATURE CELL498': [],
#  'IMMATURE CELL499': ['Olfr1357'],
#  'IMMATURE CELL500': ['Olfr292', 'Olfr938'],
#  'IMMATURE CELL501': [],
#  'IMMATURE CELL502': [],
#  'IMMATURE CELL503': [],
#  'IMMATURE CELL504': ['Olfr1112'],
#  'IMMATURE CELL505': [],
#  'IMMATURE CELL506': [],
#  'IMMATURE CELL507': [],
#  'IMMATURE CELL508': ['Olfr15', 'Olfr704', 'Olfr464'],
#  'IMMATURE CELL509': ['Olfr114', 'Olfr212'],
#  'IMMATURE CELL510': ['Olfr130', 'Olfr720'],
#  'IMMATURE CELL511': [],
#  'IMMATURE CELL512': ['Olfr1301'],
#  'IMMATURE CELL513': [],
#  'IMMATURE CELL514': [],
#  'IMMATURE CELL515': ['Olfr1346', 'Olfr960', 'Olfr1500', 'Olfr39', 'Olfr140'],
#  'IMMATURE CELL516': ['Olfr843', 'Olfr479'],
#  'IMMATURE CELL517': ['Olfr1229'],
#  'IMMATURE CELL518': [],
#  'IMMATURE CELL519': ['Olfr777', 'Olfr330'],
#  'IMMATURE CELL520': ['Olfr920', 'Olfr1500'],
#  'IMMATURE CELL521': [],
#  'IMMATURE CELL522': ['Olfr32', 'Olfr816'],
#  'IMMATURE CELL523': ['Olfr1110'],
#  'IMMATURE CELL524': [],
#  'IMMATURE CELL525': ['Olfr293', 'Olfr380'],
#  'IMMATURE CELL526': ['Olfr1080'],
#  'IMMATURE CELL527': [],
#  'IMMATURE CELL528': ['Olfr1286'],
#  'IMMATURE CELL529': ['Olfr1410', 'Olfr1013'],
#  'IMMATURE CELL530': [],
#  'IMMATURE CELL531': [],
#  'IMMATURE CELL532': ['Olfr211', 'Olfr309'],
#  'IMMATURE CELL533': ['Olfr1357'],
#  'IMMATURE CELL534': [],
#  'IMMATURE CELL535': []}

# %%
di1={}
for key,value in cell_imm_imt.items():
  di2={}
  if len(value)<1:
    continue
  else:
    for val in value:
      di2[val]=tr_exp[key][val]
    di1[key]=di2

# %%
len(di1)
# Out:
# 261

# %%
#GENERATE UNIQUE HITS
os.chdir('/home/sidrah19220/nmd_review/comment4/wild/immature')
ratio_data={}
unique_number = {}
unique_percentage = {}
for folder in range(7,10):
    di='ran_'+str(folder)
    os.mkdir(di)
    os.chdir(di) 
    import random
    for key,values in cell_mat.items():
        or_rec=olf_rec.copy()
        if len(values)==0:
            continue
        else:
            or_rec.remove(values[0])
            cell_mat[key]=random.sample(or_rec,1) 
        #A FILE IS GENERATED WITH ALL INFORMATION OF mOSN, iOSN/tOSN, THE EUCLIDEAN DISTANCE AND OR EXPRESSED
    with open("Out_data_eud_"+str(folder)+".csv","w")as fout:
        fout.write("Olfactory Receptor,Mature Cell ID,Immature/Transition Cell ID, ED,Dist. Rank,Receptor Expression Rank,Receptor Expression,Expression Diffrence from rank1\n")
        empty_mat=[]
        mat_cell=eud.index
        imm_imt_cells=list(eud.columns.values.tolist())
        for i in range(len(mat_cell)):
            mat1={}
            for j in range(len(imm_imt_cells)):
                mat1[eud.iloc[i][j]]=imm_imt_cells[j]
            euds=sorted(mat1.keys(), reverse=False)
            for j in range(len(euds)):
                if len(cell_mat[mat_cell[i]])==0:
                    empty_mat.append(mat_cell[i])
                else:
                    if cell_mat[mat_cell[i]][0] in cell_imm_imt[mat1[euds[j]]]:
                        for k in range(len(cell_imm_imt[mat1[euds[j]]])):
                            if cell_imm_imt[mat1[euds[j]]][k]==cell_mat[mat_cell[i]][0]:
                                fout.write(str(cell_imm_imt[mat1[euds[j]]][k])+','+str(mat_cell[i])+','+str(mat1[euds[j]])+','+str(euds[j])+','+str(j)+','+str(k)+','+str(di1[mat1[euds[j]]][cell_imm_imt[mat1[euds[j]]][k]])+','+str((di1[mat1[euds[j]]][cell_imm_imt[mat1[euds[j]]][0]])-di1[mat1[euds[j]]][cell_imm_imt[mat1[euds[j]]][k]])+'\n')
        
        
        #CALCULATING PERCENTILE AT DIFFERENT THRESHOLD FOR EUC DISTANCE
    eu = eud
    li = [0.01, 0.02, 0.05, 0.1, 0.2, 0.3, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
    for ki in li:
        q = eu.quantile(ki , axis = 1)
        q1 = q.tolist()
        qq = pd.DataFrame(q)

        idd = eu.index.tolist()
        ccl = eu.columns.tolist()
        d4=dict.fromkeys(idd)

        #loop to generate imm cells
        k = []
        for i in range(len(idd)):
            for j in range(len(ccl)):
                if eu.iloc[i][j] < q1[i]:
                    k.append(ccl[j])
            d4[idd[i]] = k
            k=[]

        p = []
        for i in idd:
            p.append(len(d4[i]))
        cells = pd.DataFrame.from_dict(d4, orient='index')
        cells.to_csv(str(ki)+'percentile_euc_total_immature.csv')
    
    
    #ASSIGNING THE STATUS POSITIVE AND NEGATIVE ON BASIS OF THE mOSN THAT LIE IN THAT PARTICULAR THRESHOLD
    for ki in li:
        p=pd.read_csv(str(ki)+'percentile_euc_total_immature.csv', index_col = 0)
        o = pd.read_csv('Out_data_eud_'+str(folder)+'.csv')
        o = o[o[' ED']!=0]
        dictt={}
        v =  o['Mature Cell ID'].tolist()
        v2 = o['Immature/Transition Cell ID'].tolist()
        for indx in range(len(v)):
            if v[indx]==v[indx-1]:
                dictt[v[indx]].append(v2[indx])
            else:
                dictt[v[indx]]=[]
                dictt[v[indx]].append(v2[indx])
        ke=[]
        for key in dictt:
            ke.append(key)
        pp = p.loc[ke].T
        ppp1 = pp.to_dict('list')
        dup = o
        ind = dup.index.tolist()
        stat=[]
        for i in range(0,len(dup['Immature/Transition Cell ID'])):
            if dup['Immature/Transition Cell ID'][ind[i]] in ppp1[dup['Mature Cell ID'][ind[i]]]:
                stat.append('Positive')
            else:
                stat.append('Negative')

        dup['status'] = stat
        #dup.to_csv('Final_spl_10q.csv')
        dup.to_csv(str(ki)+'percentile_neg_pos_out_data.csv')
        euk = dup[(dup['status']=='Positive') & (dup['Expression Diffrence from rank1']==0)]
        euk.to_csv(str(ki)+'_final_res.csv')

        #CREATING A DATAFRAME AT DIFFERENT PERCENTILE SHOWING RATIO OF EXPRESSED ORs HAVING HIGHEST EXPRESSION TO NON-EXPRESSED
    DF4=pd.DataFrame()
    for ki in li:
        x = pd.read_csv(str(ki)+'_final_res.csv', index_col = 0)
        o = pd.read_csv('Out_data_eud_'+str(folder)+".csv", index_col =0)
        o = o[o[' ED']!=0]
        eu = eud
        mat_uniq = eu.index.tolist()
        dictt={}
        v =  x['Mature Cell ID'].tolist()
        v2 = x['Immature/Transition Cell ID'].tolist()

        for indx in range(len(v)):
            if v[indx]==v[indx-1]:
                if v[indx] not in dictt.keys():
                    dictt[v[indx]]=[]
                dictt[v[indx]].append(v2[indx])
            else:
                dictt[v[indx]]=[]
                dictt[v[indx]].append(v2[indx])
        xa_dict={}
        for ma in mat_uniq:
            if ma in dictt.keys():
                xa_dict[ma]=len(dictt[ma])
            else:
                xa_dict[ma]=0
        df2 = pd.DataFrame.from_dict(xa_dict, orient='index')
        print(df2.value_counts())

        pos_neg = pd.read_csv(str(ki)+'percentile_neg_pos_out_data.csv')
        pos_neg2 = pos_neg[pos_neg['status'] == 'Positive']
        dictt2={}
        v =  pos_neg2['Mature Cell ID'].tolist()
        v2 = pos_neg2['Immature/Transition Cell ID'].tolist()

        for indx in range(len(v)):
            if v[indx]==v[indx-1]:
                if v[indx] not in dictt2.keys():
                    dictt2[v[indx]]=[]
                dictt2[v[indx]].append(v2[indx])
            else:
                dictt2[v[indx]]=[]
                dictt2[v[indx]].append(v2[indx])

        x_dict={}
        for ma in mat_uniq:
            if ma in dictt2.keys():
                x_dict[ma]=len(dictt2[ma])
            else:
                x_dict[ma]=0

        df3 = pd.DataFrame.from_dict(x_dict, orient='index')
        print(df3.value_counts())
        df3.columns = ['x']
        percentile = pd.read_csv(str(ki)+'percentile_euc_total_immature.csv', index_col =0)
        xny=len(percentile.columns.values.tolist())
        print(xny)
        if len(percentile.index.values.tolist())==len(df3):
            df3['y'] = xny - df3['x'] 
        xa = df2[0].values.tolist()
        df3['xa'] = xa
        df3['xay'] = df3['xa']/df3['y']
        df3.to_csv(str(ki*100)+'percentile_boxplot.csv')

        DF4[str(ki*100)+'p']=df3['xay']

    #DF4.to_csv('plot_boxplot_euclidean.csv')
    p  = o.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')['Mature Cell ID'].tolist()
    DF4.loc[p].boxplot()
    plt.xlabel('percentile')
    plt.ylabel('Xa/y')
    plt.title('Normalised data')
    plt.savefig('normalised_data_euclidean.pdf')
    plt.show()

    o_unique = o.drop_duplicates(subset = 'Mature Cell ID', keep ='first')
    mat_uniq= o_unique['Mature Cell ID'].values.tolist()
    dictt={}
    v =  o['Mature Cell ID'].tolist()
    v2 = o['Immature/Transition Cell ID'].tolist()

    for indx in range(len(v)):
        if v[indx]==v[indx-1]:

            dictt[v[indx]].append(v2[indx])
        else:
            dictt[v[indx]]=[]
            dictt[v[indx]].append(v2[indx])

    f1 = pd.read_csv('0.01_final_res.csv')
    f2 = pd.read_csv('0.02_final_res.csv')
    f5 = pd.read_csv('0.05_final_res.csv')
    f10 = pd.read_csv('0.1_final_res.csv')
    f20 = pd.read_csv('0.2_final_res.csv')
    f30 = pd.read_csv('0.3_final_res.csv')
    f50 = pd.read_csv('0.5_final_res.csv')
    f60 = pd.read_csv('0.6_final_res.csv')
    f70 = pd.read_csv('0.7_final_res.csv')
    f80 = pd.read_csv('0.8_final_res.csv')
    f90 = pd.read_csv('0.9_final_res.csv')
    f100 = pd.read_csv('1_final_res.csv')

        #PLOT OF NUMBER OF HITS
    
    liii=[f1, f2, f5, f10, f20, f30, f50, f60, f70, f80, f90, f100]
    valss=[]
    for i in liii:
        valss.append(len(i))

    x = ['1p', '2p', '5p', '10p', '20p', '30p', '50p', '60p', '70p', '80p', '90p', '100p']
    plt.bar(x,valss)
    plt.title('Count of hits')
    plt.xlabel('percentile')
    plt.ylabel('# of cells')
    plt.savefig('number of hits euclidean.pdf')
    plt.show()

    unique_f1 = f1.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f2 = f2.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f5 = f5.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f10 = f10.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f20 = f20.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f30 = f30.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f50 = f50.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f60 = f60.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f70 = f70.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f80 = f80.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f90 = f90.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')
    unique_f100 = f100.drop_duplicates(subset = 'Mature Cell ID', keep = 'first')

    
    #PLOT OF NUMBER OF UNIQUE mOSNs 

    liii=[unique_f1, unique_f2, unique_f5, unique_f10, unique_f20, unique_f30, unique_f50, unique_f60, unique_f70, unique_f80,
          unique_f90, unique_f100]
    valss_unique=[]
    for i in liii:
        valss_unique.append(len(i))

    unique_number[str(folder)]=valss_unique
    
    gra = pd.DataFrame(valss_unique)
    gra.to_csv('unique-count.csv')
    
    
    x = ['1p', '2p', '5p', '10p', '20p', '30p', '50p', '60p', '70p', '80p', '90p', '100p']
    plt.bar(x,valss_unique)
    plt.title('Count of unique hits')
    plt.xlabel('percentile')
    plt.ylabel('# of cells')
    plt.savefig('number of unique hits euclidean.pdf')
    plt.show()
    
    
    #PERCENTAGE OF UNIQUE mOSNs
    valssf=[]
    for v in valss_unique:
        valssf.append((v/261)*100)
        
    unique_percentage[str(folder)]=valssf
    
    
    gra = pd.DataFrame(valssf)
    gra.to_csv('unique-percentage.csv')
    

    plt.bar(x,valssf)
    plt.title('Percentage of unique counts')
    plt.xlabel('Percentile')
    plt.ylabel('Percentage')
    plt.savefig('percentage')
    plt.yticks([0, 20, 40, 60, 80, 100])
    plt.savefig('percentage_test_divbyunique.pdf')
    plt.show()
    
    os.chdir('/home/sidrah19220/nmd_review/comment4/wild/immature')
# Out:
# 0    535
# dtype: int64
# 0    535
# dtype: int64
# 6
# 0    535
# dtype: int64
# 0    535
# dtype: int64
# 11
# 0    534
# 1      1
# dtype: int64
# 0    534
# 1      1
# dtype: int64
# 27
# 0    533
# 1      2
# dtype: int64
# 0    530
# 1      4
# 2      1
# dtype: int64
# 54
# 0    527
# 1      7
# 2      1
# dtype: int64
# 0    522
# 1     11
# 3      2
# dtype: int64
# 107
# 0    526
# 1      8
# 2      1
# dtype: int64
# 0    520
# 1     12
# 3      2
# 2      1
# dtype: int64
# 161
# 0    514
# 1     19
# 2      2
# dtype: int64
# 0    507
# 1     20
# 2      6
# 3      1
# 4      1
# dtype: int64
# 267
# 0    507
# 1     24
# 2      4
# dtype: int64
# 0    498
# 1     25
# 2      9
# 3      2
# 4      1
# dtype: int64
# 321
# 0    500
# 1     28
# 2      7
# dtype: int64
# 0    493
# 1     30
# 2      6
# 4      4
# 3      2
# dtype: int64
# 374
# 0    497
# 1     31
# 2      4
# 3      3
# dtype: int64
# 0    490
# 1     33
# 2      6
# 4      3
# 5      2
# 3      1
# dtype: int64
# 428
# 0    492
# 1     35
# 2      5
# 3      3
# dtype: int64
# 0    481
# 1     41
# 2      6
# 5      3
# 3      2
# 4      2
# dtype: int64
# 481
# 0    489
# 1     37
# 2      6
# 3      3
# dtype: int64
# 0    478
# 1     41
# 2      9
# 4      3
# 5      3
# 3      1
# dtype: int64
# 534
# 0    535
# dtype: int64
# 0    535
# dtype: int64
# 6
# 0    535
# dtype: int64
# 0    535
# dtype: int64
# 11
# 0    532
# 1      3
# dtype: int64
# 0    532
# 1      3
# dtype: int64
# 27
# 0    530
# 1      5
# dtype: int64
# 0    529
# 1      6
# dtype: int64
# 54
# 0    518
# 1     16
# 2      1
# dtype: int64
# 0    512
# 1     21
# 2      2
# dtype: int64
# 107
# 0    514
# 1     18
# 2      3
# dtype: int64
# 0    508
# 1     23
# 2      3
# 3      1
# dtype: int64
# 161
# 0    504
# 1     27
# 2      4
# dtype: int64
# 0    493
# 1     36
# 3      4
# 2      2
# dtype: int64
# 267
# 0    495
# 1     35
# 2      5
# dtype: int64
# 0    483
# 1     43
# 2      4
# 3      4
# 4      1
# dtype: int64
# 321
# 0    491
# 1     39
# 2      5
# dtype: int64
# 0    478
# 1     47
# 2      5
# 3      4
# 4      1
# dtype: int64
# 374
# 0    487
# 1     41
# 2      7
# dtype: int64
# 0    475
# 1     47
# 2      8
# 3      3
# 4      2
# dtype: int64
# 428
# 0    486
# 1     42
# 2      5
# 3      2
# dtype: int64
# 0    472
# 1     48
# 2      8
# 3      4
# 4      2
# 5      1
# dtype: int64
# 481
# 0    481
# 1     45
# 2      7
# 3      2
# dtype: int64
# 0    468
# 1     50
# 2      9
# 4      5
# 3      2
# 5      1
# dtype: int64
# 534
# 0    534
# 1      1
# dtype: int64
# 0    534
# 1      1
# dtype: int64
# 6
# 0    532
# 1      3
# dtype: int64
# 0    532
# 1      3
# dtype: int64
# 11
# 0    531
# 1      4
# dtype: int64
# 0    531
# 1      4
# dtype: int64
# 27
# 0    530
# 1      5
# dtype: int64
# 0    529
# 1      5
# 2      1
# dtype: int64
# 54
# 0    527
# 1      8
# dtype: int64
# 0    524
# 1     10
# 2      1
# dtype: int64
# 107
# 0    519
# 1     16
# dtype: int64
# 0    512
# 1     22
# 2      1
# dtype: int64
# 161
# 0    513
# 1     21
# 2      1
# dtype: int64
# 0    502
# 1     29
# 2      4
# dtype: int64
# 267
# 0    501
# 1     30
# 2      4
# dtype: int64
# 0    487
# 1     39
# 2      9
# dtype: int64
# 321
# 0    498
# 1     31
# 2      6
# dtype: int64
# 0    482
# 1     43
# 2      9
# 4      1
# dtype: int64
# 374
# 0    495
# 1     34
# 2      4
# 3      2
# dtype: int64
# 0    478
# 1     45
# 2     10
# 4      1
# 5      1
# dtype: int64
# 428
# 0    493
# 1     36
# 2      4
# 3      2
# dtype: int64
# 0    474
# 1     49
# 2      9
# 3      1
# 4      1
# 5      1
# dtype: int64
# 481
# 0    488
# 1     41
# 2      4
# 3      2
# dtype: int64
# 0    468
# 1     54
# 2     10
# 3      1
# 4      1
# 5      1
# dtype: int64
# 534
